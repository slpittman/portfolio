// %%
val url = "http://shot.holycross.edu/ada-vases.tsv"
// Out:
// url: String = "http://shot.holycross.edu/ada-vases.tsv"

// %%
import scala.io.Source
val lines = Source.fromURL(url).getLines.toVector
lines.size
// Out:
// import scala.io.Source
//
// lines: Vector[String] = Vector(
//   "URI\tVase Number\tFabric\tTechnique\tSub Technique\tShape Name\tProvenance\tDate\tInscriptions\t Attributed To\t Decoration\t Collection Record\t Publication Record\t Inscriptions II\tMeasurements\tVolume\tWeight\tRestorations\tOrnament\t Technical Observations\tPleiades URI\tLatitude\tLongitude",
//   "<a href=\"http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04</a>\t1\tATHENIAN\tBLACK-FIGURE\t\tAMPHORA, NECK\tITALY, ETRURIA, VULCI\t-550 to -500\t\tCHIUSI P by KUNZE-GOTTE | LEAGROS GROUP by KUNZE-GOTTE\tA,B: TRIPTOLEMOS ON WINGED CHARIOT BETWEEN DEMETER AND PERSEPHONE\tMunich, Antikensammlungen: J543 | Rome, Candelori Collection | Munich, Antikensammlungen: 1539\tCorpus Vasorum Antiquorum: MUNICH, MUSEUM ANTIKER KLEINKUNST 8, 56-57, BEILAGE D4, PLS.(1816,1820,1830) 398.4,402.1-2,412.2 <a target=_blank href=browseCVARecord.asp?id={8C5C25CA-9E1C-41A2-886A-2558611DCA04}&startRef=>View Whole CVA Plates</a> | Crouwel, J.H., Chariots and other Wheeled Vehicles in Iron Age Greece, Allard Pierson Series 9 (Amsterdam, 1992): PL.26.3 (DRAWING OF PART) | Jahrbuch des Deutschen Archaologischen Instituts: 87 (1972), 81, FIGS.12, 13 (A, B)\t\t\t\t\t\t\t\t<a href=\"https://pleiades.stoa.org/places/413393\" target=\"_blank\">https://pleiades.stoa.org/places/413393</a>\t42.421429\t11.702499",
//   "<a href=\"http://www.beazley.ox.ac.uk/record/669B79A6-CACA-4CCA-8E0C-69D2C4C9172F\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/669B79A6-CACA-4CCA-8E0C-69D2C4C9172F</a>\t2\tATHENIAN\tBLACK-FIGURE\t\tKRATER, COLUMN FRAGMENT\tATHENS, AGORA\t-550 to -500\t\t\tUnder handle: VOLUTE KRATER\tAthens, Agora Museum: P13332\tThe Athenian Agora, Results of Excavations conducted by the American School of Classical Studies at Athens: 23, PL.44.463\t\t\t\t\t\t\t\t<a href=\"https://pleiades.stoa.org/places/807514119\" target=\"_blank\">https://pleiades.stoa.org/places/807514119</a>\t37.995486\t23.731327",
//   "<a href=\"http://www.beazley.ox.ac.uk/record/B7867649-B68A-4152-8243-15FCE35031C9\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/B7867649-B68A-4152-8243-15FCE35031C9</a>\t3\tATHENIAN\tBLACK-FIGURE\t\tAMPHORA, NECK\tITALY, ETRURIA, VULCI\t\t\t\tA,B: TRIPTOLEMOS AND DEMETER\tRome, Mus. Naz. Etrusco di Villa Giulia: 63614\tJahrbuch des Deutschen Archaologischen Instituts: 87 (1972), 80, FIGS.8, 9 (A, B) | Lexicon Iconographicum Mythologiae Classicae: VIII, PL.34, TRIPTOLEMOS 63 (A) | Regoli, C. (ed.) Mode e Modelli, Fortuna e insuccesso nella circolazione di cose e idee (Rome, 2012): 201, FIG.4 (A) | Riccioni, G., Vasi Greci da Vulci, Necropoli dell'Osteria scavi Ferraguti-Mengarelli 1929-1931 (Milan, 2003): FIGS.20-21 (A, B)\t\t\t\t\t\t\t\t<a href=\"https://pleiades.stoa.org/places/413393\" target=\"_blank\">https://pleiades.stoa.org/places/413393</a>\t42.421429\t11.702499",
// ...
// res1_2: Int = 117751

// %%
val byColumns = lines.map(ln => ln.split("\t").toVector)
byColumns.size
// Out:
// byColumns: Vector[Vector[String]] = Vector(
//   Vector(
//     "URI",
//     "Vase Number",
//     "Fabric",
//     "Technique",
//     "Sub Technique",
//     "Shape Name",
//     "Provenance",
//     "Date",
//     "Inscriptions",
//     " Attributed To",
//     " Decoration",
//     " Collection Record",
//     " Publication Record",
//     " Inscriptions II",
//     "Measurements",
//     "Volume",
//     "Weight",
//     "Restorations",
//     "Ornament",
//     " Technical Observations",
//     "Pleiades URI",
//     "Latitude",
//     "Longitude"
//   ),
//   Vector(
//     "<a href=\"http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04\" target=\"_blank\">http://www.beazley.ox.ac.uk/record/8C5C25CA-9E1C-41A2-886A-2558611DCA04</a>",
//     "1",
//     "ATHENIAN",
//     "BLACK-FIGURE",
//     "",
//     "AMPHORA, NECK",
//     "ITALY, ETRURIA, VULCI",
//     "-550 to -500",
//     "",
//     "CHIUSI P by KUNZE-GOTTE | LEAGROS GROUP by KUNZE-GOTTE",
// ...
// res2_1: Int = 117751

// %%
val descriptions = byColumns.filter(row => row.size == 23).map( v => v(10))
// Out:
// descriptions: Vector[String] = Vector(
//   " Decoration",
//   "A,B: TRIPTOLEMOS ON WINGED CHARIOT BETWEEN DEMETER AND PERSEPHONE",
//   "Under handle: VOLUTE KRATER",
//   "A,B: TRIPTOLEMOS AND DEMETER",
//   "A: ATHENA",
//   "Body: CHILD AND HARE",
//   "A: ATHENA, BETWEEN COLUMNS, SHIELD DEVICE, DISCS | B: MUSIC, YOUTH ON PLATFORM PLAYING PIPES BETWEEN JUDGES, SEATED",
//   "WOMAN AND SATYR",
//   "A: GIGANTOMACHY (?) HERAKLES AND ATHENA IN CHARIOT, WARRIOR, NONSENSE INSCRIPTIONS | B: HERAKLES PLAYING KITHARA AT ALTAR, IOLAOS, WOMAN, ATHENA, SHIELD DEVICE, SNAKE, NONSENSE INSCRIPTIONS | Under foot: GRAFFITO: MAN, SWASTIKA",
//   "A: MAN WITH PHIALE AND STAFF, WOMAN WITH OINOCHOE | B: WOMAN",
//   "A: SWAN BETWEEN LIONS | B: SIRENS | Neck A: SIREN | Neck B: LION",
//   "A: DIONYSOS, SATYRS, ONE WITH LYRE AND MAENAD WITH PIPES, IN SHIP | B: DIONYSOS, MAENADS AND SATYRS IN SHIP",
//   "Body: SPHINX, LIONS",
//   "Body: WEDDED PAIR IN CHARIOT, WOMEN, YOUTHS WITH HYDRIA AND KITHARA, OLD MAN SEATED | Predella: PANTHERS, DEER | Shoulder: THESEUS (IN NEBRIS) AND MINOTAUR BETWEEN ONLOOKERS (YOUTHS, SOME DRAPED, SOME WITH WREATHS), FILLETS SUSPENDED",
//   "Body: HERAKLES AND TRITON | Predella: PANTHERS, DEER | Shoulder: YOUTHS LEADING HORSES",
//   "Body: CHARIOT (CHARIOTEER IN NEBRIS), YOUTH | Shoulder: ACHILLES AND TROILOS, WOMAN AT FOUNTAIN, POLYXENE, AND YOUTH RUNNING",
//   "A: MEN DANCING (?)",
//   "DRAPED MEN, CHARIOT, HORSE, PALMETTE",
//   "A: WOMAN RUNNING WITH TORCHES | B: WOMAN RUNNING WITH BOX",
//   "A,B: GORGONEION",
//   "I: ATHENA HOLDING HELMET, SHIELD, STELE",
//   "I: MAN LEANING ON STAFF (?) FIGURE SEATED (?) ON STOOL",
//   "A: GORGONEION",
//   "A,B: GORGONEION",
//   "A: MAN, DRAWING WATER FROM PITHOS, WOMAN WITH HYDRIAI, SATYR MASTURBATING, MAENAD | B: HERAKLES AND THE BULL",
//   "A: ATHENA, NIKE",
//   "KOMOS",
//   "FLORAL, IVY CHAIN, LAUREL WREATH",
//   "Body: COCKS",
// ...

// %%
val tidier = descriptions.map(t => t.toLowerCase).map(descr => descr.replaceAll("[^a-z ]", ""))
// Out:
// tidier: Vector[String] = Vector(
//   " decoration",
//   "ab triptolemos on winged chariot between demeter and persephone",
//   "under handle volute krater",
//   "ab triptolemos and demeter",
//   "a athena",
//   "body child and hare",
//   "a athena between columns shield device discs  b music youth on platform playing pipes between judges seated",
//   "woman and satyr",
//   "a gigantomachy  herakles and athena in chariot warrior nonsense inscriptions  b herakles playing kithara at altar iolaos woman athena shield device snake nonsense inscriptions  under foot graffito man swastika",
//   "a man with phiale and staff woman with oinochoe  b woman",
//   "a swan between lions  b sirens  neck a siren  neck b lion",
//   "a dionysos satyrs one with lyre and maenad with pipes in ship  b dionysos maenads and satyrs in ship",
//   "body sphinx lions",
//   "body wedded pair in chariot women youths with hydria and kithara old man seated  predella panthers deer  shoulder theseus in nebris and minotaur between onlookers youths some draped some with wreaths fillets suspended",
//   "body herakles and triton  predella panthers deer  shoulder youths leading horses",
//   "body chariot charioteer in nebris youth  shoulder achilles and troilos woman at fountain polyxene and youth running",
//   "a men dancing ",
//   "draped men chariot horse palmette",
//   "a woman running with torches  b woman running with box",
//   "ab gorgoneion",
//   "i athena holding helmet shield stele",
//   "i man leaning on staff  figure seated  on stool",
//   "a gorgoneion",
//   "ab gorgoneion",
//   "a man drawing water from pithos woman with hydriai satyr masturbating maenad  b herakles and the bull",
//   "a athena nike",
//   "komos",
//   "floral ivy chain laurel wreath",
//   "body cocks",
// ...

// %%
val k = 11
val iterations = 20
val stopWords = Array("the", "a", "and", "with", "holding", "for", "into", "between", "among", "some", "from", "around", "shoulder", "body", "neck", "handle", "all", "one", "two", "lid", "rim", "obverse", "zone", "reverse", "towards", "toward", "signatures", "signature", "inscription", "inscriptions", "undecorated", "part", "uncertain", "without", "both")
val vocabSize = 10000
val minimumTokenLength = 3
val termsToDisplay = 15
// Out:
// k: Int = 11
// iterations: Int = 20
// stopWords: Array[String] = Array(
//   "the",
//   "a",
//   "and",
//   "with",
//   "holding",
//   "for",
//   "into",
//   "between",
//   "among",
//   "some",
//   "from",
//   "around",
//   "shoulder",
//   "body",
//   "neck",
//   "handle",
//   "all",
//   "one",
//   "two",
//   "lid",
//   "rim",
//   "obverse",
//   "zone",
//   "reverse",
//   "towards",
//   "toward",
//   "signatures",
//   "signature",
//   "inscription",
//   "inscriptions",
//   "undecorated",
//   "part",
//   "uncertain",
//   "without",
//   "both"
// )
// vocabSize: Int = 10000
// minimumTokenLength: Int = 3
// termsToDisplay: Int = 15

// %%
import $ivy.`org.apache.spark::spark-sql:2.4.5`
import org.apache.spark.sql._
import $ivy.`org.apache.spark::spark-mllib:2.4.5`
// Out:
// import $ivy.$
//
// import org.apache.spark.sql._
//
// import $ivy.$

// %%
import org.apache.log4j.{Level, Logger}
Logger.getLogger("org").setLevel(Level.OFF)
// Out:
// import org.apache.log4j.{Level, Logger}

// %%
val spark = {
  NotebookSparkSession.builder()
    .master("local[*]")
    .getOrCreate()
}
// Out:
// Loading spark-stubs
// Getting spark JARs
// Creating SparkSession
// Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
// <a href="http://jupyter-slpittman-2dclas299-2dhtmllfsf:4040">Spark UI</a>
// spark: SparkSession = org.apache.spark.sql.SparkSession@4d0e063b

// %%
import org.apache.spark.ml.clustering.LDA
import org.apache.spark.ml.feature.RegexTokenizer
import org.apache.spark.ml.feature.StopWordsRemover
import org.apache.spark.ml.feature.CountVectorizer
import org.apache.spark.mllib.linalg.Vector
import scala.collection.mutable.WrappedArray
import org.apache.spark.sql.types.IntegerType
import org.apache.spark.sql.functions._
// Out:
// import org.apache.spark.ml.clustering.LDA
//
// import org.apache.spark.ml.feature.RegexTokenizer
//
// import org.apache.spark.ml.feature.StopWordsRemover
//
// import org.apache.spark.ml.feature.CountVectorizer
//
// import org.apache.spark.mllib.linalg.Vector
//
// import scala.collection.mutable.WrappedArray
//
// import org.apache.spark.sql.types.IntegerType
//
// import org.apache.spark.sql.functions._

// %%
val txtRdd = spark.sparkContext.parallelize(tidier).zipWithIndex
// Out:
// txtRdd: org.apache.spark.rdd.RDD[(String, Long)] = ZippedWithIndexRDD[1] at zipWithIndex at cmd10.sc:1

// %%
import spark.sqlContext.implicits._

val corpus_df = txtRdd.toDF("corpus", "id")
// Out:
// import spark.sqlContext.implicits._
//
//
// corpus_df: DataFrame = [corpus: string, id: bigint]

// %%
implicit class RichDF(val df: DataFrame) {
  def showHTML(limit:Int = 20, truncate: Int = 20) = {
    import xml.Utility.escape
    val data = df.take(limit)
    val header = df.schema.fieldNames.toSeq
    val rows: Seq[Seq[String]] = data.map { row =>
      row.toSeq.map { cell =>
        val str = cell match {
          case null => "null"
          case binary: Array[Byte] => binary.map("%02X".format(_)).mkString("[", " ", "]")
          case array: Array[_] => array.mkString("[", ", ", "]")
          case seq: Seq[_] => seq.mkString("[", ", ", "]")
          case _ => cell.toString
        }
        if (truncate > 0 && str.length > truncate) {
          if (truncate < 4) str.substring(0, truncate)
          else str.substring(0, truncate - 3) + "..."
        } else {
          str
        }
      }: Seq[String]
    }

    publish.html(s"""
      <table class="table">
        <tr>
        ${header.map(h => s"<th>${escape(h)}</th>").mkString}
        </tr>
        ${rows.map { row =>
          s"<tr>${row.map { c => s"<td>${escape(c)}</td>" }.mkString}</tr>"
        }.mkString
        }
      </table>""")
  }
}
// Out:
// defined class RichDF

// %%
val tokenizer = new RegexTokenizer().setPattern("[\\W_]+").setMinTokenLength(minimumTokenLength).setInputCol("corpus").setOutputCol("tokens")
val tokenized_df = tokenizer.transform(corpus_df)
// Out:
// tokenizer: RegexTokenizer = regexTok_fba6ac50275c
// tokenized_df: DataFrame = [corpus: string, id: bigint ... 1 more field]

// %%
val remover = new StopWordsRemover().setStopWords(stopWords).setInputCol("tokens").setOutputCol("filtered")
val filtered_df = remover.transform(tokenized_df)
// Out:
// remover: StopWordsRemover = stopWords_fc1af0ab081d
// filtered_df: DataFrame = [corpus: string, id: bigint ... 2 more fields]

// %%
val vectorizer = new CountVectorizer().setInputCol("filtered").setOutputCol("features").setVocabSize(vocabSize).setMinDF(5).fit(filtered_df)
val countVectors = vectorizer.transform(filtered_df).select("id", "features")
// Out:
// <script>
// var comm = Jupyter.notebook.kernel.comm_manager.new_comm('cancel-stage-b45f3c07-c7a2-4206-aac2-50e2135ca744', {});
//
// function cancelStage(stageId) {
//   console.log('Cancelling stage ' + stageId);
//   comm.send({ 'stageId': stageId });
// }
// </script>
// <div>
//   <span style="float: left;">flatMap at CountVectorizer.scala:205</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">count at CountVectorizer.scala:230</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">top at CountVectorizer.scala:233</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// vectorizer: org.apache.spark.ml.feature.CountVectorizerModel = cntVec_8e7e94bc5919
// countVectors: DataFrame = [id: bigint, features: vector]

// %%
val lda = new LDA().setK(k).setMaxIter(iterations)
val model = lda.fit(countVectors)
// Out:
// <div>
//   <span style="float: left;">count at LDAOptimizer.scala:419</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">first at LDAOptimizer.scala:420</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// 20/05/06 16:59:51 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeSystemBLAS
// 20/05/06 16:59:51 WARN BLAS: Failed to load implementation from: com.github.fommil.netlib.NativeRefBLAS
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">isEmpty at LDAOptimizer.scala:450</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">treeAggregate at LDAOptimizer.scala:504</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// lda: LDA = lda_52fe389d5d65
// model: org.apache.spark.ml.clustering.LDAModel = lda_52fe389d5d65

// %%
val topics = model.describeTopics(termsToDisplay)
// Out:
// topics: DataFrame = [topic: int, termIndices: array<int> ... 1 more field]

// %%
topics.showHTML(truncate=1000)
// Out:
//       <table class="table">
//         <tr>
//         <th>topic</th><th>termIndices</th><th>termWeights</th>
//         </tr>
446, 342, 284, 291, 496, 602, 116, 642, 18, 739, 391, 942, 905, 787, 666]</td><td>[0.019230770393598183, 0.018475660836068362, 0.018032846951865415, 0.017598796070459097, 0.012587746816491984, 0.010471245715115096, 0.0067840825182497394, 0.006520483267776433, 0.00617930905184246, 0.005446571479339898, 0.005185556632102864, 0.005136631389859689, 0.005002212425707252, 0.0049749043379305035, 0.004735924154069464]</td></tr><tr><td>8</td><td>[12, 38, 20, 93, 47, 81, 117, 78, 72, 146, 188, 169, 223, 198, 160]</td><td>[0.09734601778050864, 0.08169999302855566, 0.06883462905067654, 0.044954750022085904, 0.03616134656942815, 0.03347981401242452, 0.03263744563496845, 0.02529132247694998, 0.021075997654648727, 0.019161615161180708, 0.018900260883830938, 0.01770413656563269, 0.01428025695097647, 0.011965329144628709, 0.011875359049555279]</td></tr><tr><td>9</td><td>[76, 17, 16, 102, 163, 124, 183, 172, 151, 152, 219, 156, 103, 36, 289]</td><td>[0.06642668470669032, 0.04316164751133965, 0.035009667404310094, ...
//       </table>

// %%
val topicLabels = topics.select("termIndices").map { case Row(r:  WrappedArray[Integer]) => r.map( i => vectorizer.vocabulary(i) ) }
val labelsNumberedLong = topicLabels.rdd.zipWithIndex.toDF("terms", "topicLong")
val labelsIndexed = labelsNumberedLong.withColumn("topic", $"topicLong".cast(IntegerType)).drop("topicLong")

val topicsWithTerms = labelsIndexed.join(topics, labelsIndexed.col("topic") === topics.col("topic")).drop(labelsIndexed.col("topic"))
// Out:
// topicLabels: Dataset[WrappedArray[String]] = [value: array<string>]
// labelsNumberedLong: DataFrame = [terms: array<string>, topicLong: bigint]
// labelsIndexed: DataFrame = [terms: array<string>, topic: int]
// topicsWithTerms: DataFrame = [terms: array<string>, topic: int ... 2 more fields]

// %%
val weightedLabels = topicsWithTerms.withColumn("termsWithWeight", expr("zip_with(terms, termWeights, (t,w) -> concat(t, ' ', w))"))
// Out:
// weightedLabels: DataFrame = [terms: array<string>, topic: int ... 3 more fields]

// %%
weightedLabels.select("topic", "termsWithWeight").showHTML(truncate=1000)
// Out:
// <div>
//   <span style="float: left;">run at ThreadPoolExecutor.java:1149</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
// <div>
//   <span style="float: left;">take at cmd12.sc:4</span>
// </div>
// <div class="progress">
//   <div class="progress-bar" role="progressbar" style="background-color: blue; width: 100%; word-wrap: normal; white-space: nowrap; text-align: center; color: white" aria-valuenow="100" aria-valuemin="0" aria-valuemax="100">
//     1 / 1
//   </div>
//   <div class="progress-bar" role="progressbar" style="background-color: red; width: 0%" aria-valuenow="0" aria-valuemin="0" aria-valuemax="100"></div>
// </div>
//       <table class="table">
//         <tr>
//         <th>topic</th><th>termsWithWeight</th>
//         </tr>
//         <tr><td>0</td><td>[seated 0.06154684278178771, woman 0.04240026327517918, dionysos 0.036613738396286295, maenad 0.030223065443465254, women 0.029669530855946792, satyr 0.028731931635003916, chariot 0.024809103740859352, thyrsos 0.023875347342898288, maenads 0.02093098751389732, satyrs 0.018369581987961594, eros 0.01626402040333153, hermes 0.016089848381495256, dancing 0.015412471977696471, domestic 0.015217608818611297, stool 0.014892484905352707]</td></tr><tr><td>1</td><td>[fish 0.02159156339409686, wedding 0.009702233866085933, cave 0.00922848536684775, agriculture 0.009028784868310682, picking 0.008357331750227254, splanchnopt 0.0075099423284451326, tendrils 0.006803826996137123, hetaira 0.0058020206503172495, clothes 0.005649561735314312, shells 0.0054382801977